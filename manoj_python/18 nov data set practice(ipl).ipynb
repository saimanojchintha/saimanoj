# %%
import pandas as pd
import numpy as nm

# %%
df=pd.read_csv(r'C:\Users\sairam\Desktop\m@noj\deliveries.csv')
df.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
df.isnull().sum()                                #to find null values
# Out:
# match_id                 0
# inning                   0
# batting_team             0
# bowling_team             0
# over                     0
# ball                     0
# batsman                  0
# non_striker              0
# bowler                   0
# is_super_over            0
# wide_runs                0
# bye_runs                 0
# legbye_runs              0
# noball_runs              0
# penalty_runs             0
# batsman_runs             0
# extra_runs               0
# total_runs               0
# player_dismissed    143022
# dismissal_kind      143022
# fielder             145091
# dtype: int64

# %% [markdown]
# # handling null values

# %%
df.player_dismissed.isnull().sum()
# Out:
# 143022

# %%
df.player_dismissed.mode()
# Out:
# 0    SK Raina
# Name: player_dismissed, dtype: object

# %%
df['player_dismissed']=df['player_dismissed'].fillna(df['player_dismissed'].mode()[0])
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df.player_dismissed.isnull().sum()
# Out:
# 0

# %%
df.dismissal_kind.isnull().sum()
# Out:
# 143022

# %%
df.dismissal_kind.mode()
# Out:
# 0    caught
# Name: dismissal_kind, dtype: object

# %%
df['dismissal_kind']=df['dismissal_kind'].fillna(df['dismissal_kind'].mode()[0])
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df.player_dismissed.isnull().sum()
# Out:
# 0

# %%
df.fielder.isnull().sum()
# Out:
# 145091

# %%
df.fielder.mode()
# Out:
# 0    KD Karthik
# Name: fielder, dtype: object

# %%
df['fielder']=df['fielder'].fillna(df['fielder'].mode()[0])
df
# Out:
#         match_id  inning                 batting_team  \
# 0              1       1          Sunrisers Hyderabad
# 1              1       1          Sunrisers Hyderabad
# 2              1       1          Sunrisers Hyderabad
# 3              1       1          Sunrisers Hyderabad
# 4              1       1          Sunrisers Hyderabad
# ...          ...     ...                          ...
# 150455       636       2  Royal Challengers Bangalore
# 150456       636       2  Royal Challengers Bangalore
# 150457       636       2  Royal Challengers Bangalore
# 150458       636       2  Royal Challengers Bangalore
# 150459       636       2  Royal Challengers Bangalore
#
#                        bowling_team  over  ball        batsman    non_striker  \
# 0       Royal Challengers Bangalore     1     1      DA Warner       S Dhawan
# 1       Royal Challengers Bangalore     1     2      DA Warner       S Dhawan
# 2       Royal Challengers Bangalore     1     3      DA Warner       S Dhawan
# ...

# %%
df.fielder.isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# match_id            0
# inning              0
# batting_team        0
# bowling_team        0
# over                0
# ball                0
# batsman             0
# non_striker         0
# bowler              0
# is_super_over       0
# wide_runs           0
# bye_runs            0
# legbye_runs         0
# noball_runs         0
# penalty_runs        0
# batsman_runs        0
# extra_runs          0
# total_runs          0
# player_dismissed    0
# dismissal_kind      0
# fielder             0
# dtype: int64

# %%
df['is_super_over'].max()                #maximum super overs bowled by bowler
# Out:
# 1

# %%
df1=df.loc[df['is_super_over'] == 1,['bowler']]
df1
# Out:
#              bowler
# 8092    JP Faulkner
# 8093    JP Faulkner
# 8094    JP Faulkner
# 8095    JP Faulkner
# 8096    JP Faulkner
# ...             ...
# 127365    CH Morris
# 127366   MG Johnson
# 127367   MG Johnson
# 127368   MG Johnson
# 127369   MG Johnson
#
# [81 rows x 1 columns]

# %%
df['is_super_over'].min()               #minimun super overs bowled by bowler
# Out:
# 0

# %%
df1=df.loc[df['is_super_over'] == 0,['bowler']]
df1
# Out:
#           bowler
# 0       TS Mills
# 1       TS Mills
# 2       TS Mills
# 3       TS Mills
# 4       TS Mills
# ...          ...
# 150455   B Kumar
# 150456   B Kumar
# 150457   B Kumar
# 150458   B Kumar
# 150459   B Kumar
#
# [150379 rows x 1 columns]

# %%
df['batsman_runs'].max()                                             #max runs by batsmen
# Out:
# 6

# %%
df2=df.loc[df['batsman_runs'] == 6,['batsman']]
df2
# Out:
#              batsman
# 10         DA Warner
# 47      MC Henriques
# 75      Yuvraj Singh
# 89      Yuvraj Singh
# 91      MC Henriques
# ...              ...
# 150395       V Kohli
# 150413       V Kohli
# 150428     SR Watson
# 150440     STR Binny
# 150453   Sachin Baby
#
# [6523 rows x 1 columns]

# %%
df['batsman_runs'].min()                                            #min runs by bowler
# Out:
# 0

# %%
df2=df.loc[df['batsman_runs'] == 0,['batsman']]
df2
# Out:
#               batsman
# 0           DA Warner
# 1           DA Warner
# 3           DA Warner
# 4           DA Warner
# 5            S Dhawan
# ...               ...
# 150446      STR Binny
# 150450      CJ Jordan
# 150451      CJ Jordan
# 150456    Sachin Baby
# 150457  Iqbal Abdulla
#
# [61148 rows x 1 columns]

# %%
df.batsman.value_counts().sum()                                                           #no of batsman
# Out:
# 150460

# %%
df.batsman
# Out:
# 0             DA Warner
# 1             DA Warner
# 2             DA Warner
# 3             DA Warner
# 4             DA Warner
#               ...
# 150455      Sachin Baby
# 150456      Sachin Baby
# 150457    Iqbal Abdulla
# 150458      Sachin Baby
# 150459    Iqbal Abdulla
# Name: batsman, Length: 150460, dtype: object

# %%
df.bowler                                                          #no of bowlers
# Out:
# 0         TS Mills
# 1         TS Mills
# 2         TS Mills
# 3         TS Mills
# 4         TS Mills
#             ...
# 150455     B Kumar
# 150456     B Kumar
# 150457     B Kumar
# 150458     B Kumar
# 150459     B Kumar
# Name: bowler, Length: 150460, dtype: object

# %%
df.bowler.value_counts().sum()
# Out:
# 150460
