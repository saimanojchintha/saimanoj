# %%
"""#%run opd.ipynb
#%run doctor.ipynb
# %run appointment.ipynb
while(True):
    print('=' * 90)
    print('1.Opd\n2.Doctor Details\n3.Appointments\n4 Reports')
    print('=' * 90)
    choice=input("enter yor choice: ")
    if choice=="1":
        while(True):
            print('='*90)
            print('1.New Opd\n2.Edit Opd\n3.Delete Opd\n4.Search Opd\n5.Back to main menu')
            print('='*90)
            option=input("enter your option: ")
            if option=='1':
                new_opd()
            elif option=='2':
                edit_opd()
            elif option == '3':
                delete_opd()
                confirm_delete = input("Are you sure you want to delete a record? (yes/no): ").lower()
                if confirm_delete == 'yes':
                    continue
                else:
                    print("Deletion canceled.")
            elif option=='4':
                search_opd()
            elif option == '5':
                print("Exiting the program.")
                break  
            else:
                print("Invalid option. Please choose again.")
                
    elif choice=='2':
        while(True):
            print('='*90)
            print('1.New doc\n2.Edit doc details\n3.Delete doc details\n4.Search doc details\n5.Back to main menu')
            print('='*90)
            option=input("enter your option: ")
            if option=='1':
                add_doc()
            elif option=='2':
                edit_doc()
            elif option == '3':
                delete_doc()
                confirm_delete = input("Are you sure you want to delete a record? (yes/no): ").lower()
                if confirm_delete == 'yes':
                    continue
                else:
                    print("Deletion canceled.")
            elif option=='4':
                search_doc()
            elif option == '5':
                print("Exiting the program.")
                break  
            else:
                print("Invalid option. Please choose again.")
    elif choice=='3':
        while(True):
            print('='*90)
            print('1.New Appointment\n2.Edit Appointment\n3.Back to main menu')
            print('='*90)
            option=input("enter your option: ")
            if option=='1':
                add_appointment()
            #elif option=='2':
                #edit_appointment()
                #pass
            #elif option=='3':
                #print('Exiting from appointment module')
                #break
            else:
                print("Invalid option. Please choose again.")"""

# %%
# %run kotha_opd.ipynb
# %run doctor.ipynb
# %run appointment.ipynb
print('='*90)
while(True):
    print('=' * 90)
    print('1.Doctor Details\n2.Opd\n3.Appointments\n4.Reports\n5.exit')
    print('=' * 90)
    choice=input("enter yor choice: ")
    if choice=="1":
        while(True):
            print('='*90)
            print('1.New doc\n2.Edit doc details\n3.Delete doc details\n4.Search doc details\n5.Back to main menu')
            print('='*90)
            option=input("enter your option: ")
            if option=='1':
                view_existing_doctor_records()
                add_doc()
            elif option=='2':
                view_existing_doctor_records()
                edit_doc()
            elif option == '3':
                view_existing_doctor_records()
                delete_doc()
                confirm_delete = input("Are you sure you want to delete a record? (yes/no): ").lower()
                if confirm_delete == 'yes':
                    continue
                else:
                    print("Deletion canceled.")
            elif option=='4':
                view_existing_doctor_records()
                search_doc()
            elif option == '5':
                print("Exiting the program.")
                break  
            else:
                print("Invalid option. Please choose again.")
                
    elif choice=='2':
        while(True):
            print('='*90)
            print('1.New Opd\n2.Edit Opd\n3.Delete Opd\n4.Search Opd\n5.Back to main menu')
            print('='*90)
            option=input("enter your option: ")
            if option=='1':
                view_existing_opd_records()
                new_opd()
            elif option=='2':
                view_existing_opd_records()
                edit_opd()
            elif option == '3':
                view_existing_opd_records()
                delete_opd()
                confirm_delete = input("Are you sure you want to delete a record? (yes/no): ").lower()
                if confirm_delete == 'yes':
                    continue
                else:
                    print("Deletion canceled.")
            elif option=='4':
                view_existing_opd_records()
                search_opd()
            elif option == '5':
                print("Exiting the program.")
                break  
            else:
                print("Invalid option. Please choose again.")
                
    elif choice=='3':
        while(True):
            print('='*90)
            print('1.New Appointment\n2.Edit Appointment\n3.Back to main menu')
            print('='*90)
            ur_option=input("enter your option: ")
            if ur_option=='1':
                view_existing_appointment_records()
                add_appointment()
            elif ur_option=='2':
                view_existing_appointment_records()
                update_appointment()
                print("updated successfully")
            elif ur_option=='3':
                print('Exiting from appointment module')
                break
            else:
                print("Invalid option. Please choose again.")
